# %%
import functions as fc
import pandas as pd

# %%
#Executar os dados.py antes!!!
advogado_idade_genero = pd.read_excel('./data/advogados_idade_genero.xlsx')
advogado_idade_genero.head(10)
# Out:
#   Estado  Advogado(a)  Estagiário(a)  Suplementar  % Share Adv  Feminino  \
# 0     AC         3941             44          522         87.4      1880
# 1     AL        15060             21          948         94.0      7290
# 2     AM        15431             18         1544         90.8      7994
# 3     AP         4130             18          611         86.8      2098
# 4     BA        61262            401         3982         93.3     32838
# 5     CE        39273             79         1423         96.3     19243
# 6     DF        51475            295         7288         87.2     26349
# 7     ES        27232             43         2070         92.8     14332
# 8     GO        53019            262         4744         91.4     28098
# 9     MA        23532             75         2019         91.8     11748
#
#    Masculino  % De mulheres  Até25f  26até40f  41até59f  60maisf  Até25m  \
# 0       2061           47.7     126       955       658      297      91
# ...

# %%
grafico_idade = fc.criar_piramide_etaria(advogado_idade_genero, 'SP')

# %%
distribuicao_genero = fc.distribuir_genero(advogado_idade_genero)
